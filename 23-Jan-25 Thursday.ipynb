# %%
import seaborn as sns

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.scatterplot(df[['fare','age']])
# Out:
# <Axes: >

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.sample(6)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 666         0       2    male  25.0      0      0  13.0000        S  Second
# 783         0       3    male   NaN      1      2  23.4500        S   Third
# 100         0       3  female  28.0      0      0   7.8958        S   Third
# 276         0       3  female  45.0      0      0   7.7500        S   Third
# 619         0       2    male  26.0      0      0  10.5000        S  Second
# 530         1       2  female   2.0      1      1  26.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 666    man        True  NaN  Southampton    no   True
# 783    man        True  NaN  Southampton    no  False
# 100  woman       False  NaN  Southampton    no   True
# 276  woman       False  NaN  Southampton    no   True
# 619    man        True  NaN  Southampton    no   True
# 530  child       False  NaN  Southampton   yes  False

# %%
df.shape
# Out:
# (891, 15)

# %%
df.describe() # it gives descriptive statistics
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df['alive'].value_counts()
# Out:
# alive
# no     549
# yes    342
# Name: count, dtype: int64

# %%
df['pclass'].value_counts()
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(df,x='class',hue='survived')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(df,x='survived')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(df,x='embarked')
# Out:
# <Axes: xlabel='embarked', ylabel='count'>

# %%
sns.countplot(df,x='embarked',hue='sex')
# Out:
# <Axes: xlabel='embarked', ylabel='count'>

# %%
sns.countplot(df,x='sex',hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(df,hue='class',x='survived')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(df,x='embarked',hue='survived')
# Out:
# <Axes: xlabel='embarked', ylabel='count'>

# %%
df['fare'].value_counts()
# Out:
# fare
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 35.0000     1
# 28.5000     1
# 6.2375      1
# 14.0000     1
# 10.5167     1
# Name: count, Length: 248, dtype: int64

# %%
sns.countplot(df,x='fare',hue='sex')
# Out:
# <Axes: xlabel='fare', ylabel='count'>

# %%
sns.barplot(df,x='sex',y='fare',errorbar=('ci',False)) # ci -> count interpretation
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.barplot(df,x='survived',y='fare',errorbar=('ci',False))
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
sns.pointplot(df,x='survived',y='age',errorbar=('ci',False))
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.barplot(df,x='survived',y='age',errorbar=('ci',False))
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.boxplot(df,x='survived',y='age')
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
def fun(a,b,c):
    print("a =",a)
    print("b =",b)
    print("c =",c)

print("Positional Arguments:")
fun(3,5,6)
print("Keyword Arguments:")
fun(a=5,c=3,b=4)
# Out:
# Positional Arguments:
# a = 3
# b = 5
# c = 6
# Keyword Arguments:
# a = 5
# b = 4
# c = 3
